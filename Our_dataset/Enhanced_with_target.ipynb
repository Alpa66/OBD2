# %%
from sliding_window_dataset import SlidingWindowDataset
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('with_oil.csv', parse_dates=['datetime'])
dfx = df.iloc[:, -5:]
# Extract datetime features
df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month
df['day'] = df['datetime'].dt.day
df['dayofweek'] = df['datetime'].dt.dayofweek

# Move new columns right after the index column (assumed to be the first column)
cols = list(df.columns)
# Remove the datetime and new columns from their current positions
cols.remove('datetime')
for col in ['trip_number', 'year', 'month', 'day', 'dayofweek']:
    cols.remove(col)
# Insert new columns after the index column (position 1)
for i, col in enumerate(['trip_number', 'year', 'month', 'day', 'dayofweek']):
    cols.insert(i, col)
# Drop datetime and reorder colaumns
df = df[cols]
df = df.set_index(['trip_number', df.index])
df = df.iloc[:, 4:-9]
scaler = StandardScaler()
df[df.columns] = scaler.fit_transform(df)

df.head()
# Out:
#                     RPM       THR      Fdet    Speed      Twat       INJ  \
# trip_number
# 1           0 -1.188042 -0.774647 -0.129733 -1.14949  2.137515 -0.546603
#             1 -1.190809 -0.774647 -0.129733 -1.14949  2.137515 -0.558783
#             2 -1.187489 -0.774647 -0.129733 -1.14949  2.137515 -0.549648
#             3 -1.190809 -0.774647 -0.129733 -1.14949  2.137515 -0.567918
#             4 -1.190809 -0.774647 -0.129733 -1.14949  2.137515 -0.549648
#
#                     AIR       GBC   ADC_LAM       UOZ     Press     COEFF  \
# trip_number
# 1           0 -0.768447 -0.741901 -1.083910 -0.799740 -0.586234  0.803674
#             1 -0.770018 -0.748435  0.648997 -0.745914 -0.580413 -0.572897
#             2 -0.770804 -0.754585 -1.214696 -0.888169 -0.583647  0.344817
#             3 -0.771590 -0.755354  0.714390 -0.684398 -0.575454 -1.031754
#             4 -0.771590 -0.753432 -1.280088 -0.745914 -0.579335  0.344817
#
#                    Tair       Fxx      Ubat       TPS      Gear
# trip_number
# 1           0  1.121436  0.061847 -1.371310 -0.848896 -0.874425
#             1  1.121436  0.061847  0.157012 -0.848896 -0.874425
#             2  1.121436  0.061847 -0.607149 -0.848896 -0.874425
#             3  1.121436  0.061847 -1.371310 -0.848896 -0.874425
#             4  1.121436  0.061847 -1.371310 -0.848896 -0.874425

# %%
df.columns
# Out:
# Index(['RPM', 'THR', 'Fdet', 'Speed', 'Twat', 'INJ', 'AIR', 'GBC', 'ADC_LAM',
#        'UOZ', 'Press', 'COEFF', 'Tair', 'Fxx', 'Ubat', 'TPS', 'Gear'],
#       dtype='object')

# %%
df = df.dropna()
dataset = SlidingWindowDataset(df, target=None, window_size=60, stride=60)
print(len(dataset))
print(dataset[0])
# Out:
# Building safe windows: 100%|██████████| 187/187 [00:00<00:00, 796.70it/s]
# 7803
# (tensor([[-1.1880, -0.7746, -0.1297,  ..., -1.3713, -0.8489, -0.8744],
#         [-1.1908, -0.7746, -0.1297,  ...,  0.1570, -0.8489, -0.8744],
#         [-1.1875, -0.7746, -0.1297,  ..., -0.6071, -0.8489, -0.8744],
#         ...,
#         [-1.0060, -0.6302, -0.1297,  ...,  0.1570, -0.8489, -0.8744],
#         [-1.1156, -0.7024, -0.1297,  ..., -1.3713, -0.8489, -0.8744],
#         [-1.1421, -0.7024, -0.1297,  ..., -0.6071, -0.8489, -0.8744]]), tensor([-1.1421, -0.7024, -0.1297, -1.0515,  2.3473, -0.3913, -0.7252, -0.5724,
#         -1.1166, -0.9151, -0.3847,  2.1802,  1.2205,  0.0618, -0.6071, -0.8489,
#         -0.8744]))

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Собираем все окна в массив
X = np.stack([window.numpy().flatten() for window, _ in dataset])

# PCA до 2 компонент
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Визуализация
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], alpha=0.5)
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('PCA of Sliding Windows')
plt.show()

# %%
from torch.utils.data import DataLoader

loader = DataLoader(dataset, batch_size=128, shuffle=True)

# %%
import torch.nn as nn

class MLPAutoencoder(nn.Module):
    def __init__(self, input_dim, bottleneck_dim=40):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, bottleneck_dim),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(bottleneck_dim, 128),
            nn.ReLU(),
            nn.Linear(128, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        out = self.decoder(z)
        return out

# %%
import torch
import torch.optim as optim

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
input_dim = dataset[0][0].numel()
model = MLPAutoencoder(input_dim=input_dim, bottleneck_dim=40).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

for epoch in range(100):  # увеличьте число эпох по необходимости
    model.train()
    total_loss = 0
    for batch, _ in loader:
        batch = batch.view(batch.size(0), -1).to(device)
        optimizer.zero_grad()
        output = model(batch)
        loss = criterion(output, batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * batch.size(0)
    print(f"Epoch {epoch+1}, Loss: {total_loss / len(dataset):.6f}")
# Out:
# Epoch 1, Loss: 0.628616
# Epoch 2, Loss: 0.431204
# Epoch 3, Loss: 0.360997
# Epoch 4, Loss: 0.327287
# Epoch 5, Loss: 0.307812
# Epoch 6, Loss: 0.294057
# Epoch 7, Loss: 0.283084
# Epoch 8, Loss: 0.274542
# Epoch 9, Loss: 0.268357
# Epoch 10, Loss: 0.262842
# Epoch 11, Loss: 0.260443
# Epoch 12, Loss: 0.254513
# Epoch 13, Loss: 0.252600
# Epoch 14, Loss: 0.248876
# Epoch 15, Loss: 0.243416
# Epoch 16, Loss: 0.245827
# Epoch 17, Loss: 0.247280
# Epoch 18, Loss: 0.237870
# Epoch 19, Loss: 0.251523
# Epoch 20, Loss: 0.244938
# Epoch 21, Loss: 0.235738
# Epoch 22, Loss: 0.229840
# Epoch 23, Loss: 0.227031
# Epoch 24, Loss: 0.228460
# Epoch 25, Loss: 0.231142
# Epoch 26, Loss: 0.239772
# Epoch 27, Loss: 0.229067
# Epoch 28, Loss: 0.224303
# Epoch 29, Loss: 0.222350
# Epoch 30, Loss: 0.223606
# Epoch 31, Loss: 0.228090
# Epoch 32, Loss: 0.227969
# Epoch 33, Loss: 0.221518
# Epoch 34, Loss: 0.220447
# Epoch 35, Loss: 0.215818
# Epoch 36, Loss: 0.219327
# Epoch 37, Loss: 0.219930
# Epoch 38, Loss: 0.215054
# Epoch 39, Loss: 0.215695
# Epoch 40, Loss: 0.213941
# Epoch 41, Loss: 0.215155
# Epoch 42, Loss: 0.214452
# Epoch 43, Loss: 0.215972
# Epoch 44, Loss: 0.212763
# Epoch 45, Loss: 0.211439
# Epoch 46, Loss: 0.210759
# Epoch 47, Loss: 0.210520
# Epoch 48, Loss: 0.210900
# Epoch 49, Loss: 0.211259
# Epoch 50, Loss: 0.208854
# Epoch 51, Loss: 0.209054
# Epoch 52, Loss: 0.208837
# Epoch 53, Loss: 0.209191
# Epoch 54, Loss: 0.208421
# Epoch 55, Loss: 0.207466
# Epoch 56, Loss: 0.205521
# Epoch 57, Loss: 0.207405
# Epoch 58, Loss: 0.206975
# Epoch 59, Loss: 0.206985
# Epoch 60, Loss: 0.206890
# Epoch 61, Loss: 0.205527
# Epoch 62, Loss: 0.204263
# Epoch 63, Loss: 0.203518
# Epoch 64, Loss: 0.203012
# Epoch 65, Loss: 0.204228
# Epoch 66, Loss: 0.202397
# Epoch 67, Loss: 0.204349
# Epoch 68, Loss: 0.202847
# Epoch 69, Loss: 0.202016
# Epoch 70, Loss: 0.201391
# Epoch 71, Loss: 0.200959
# Epoch 72, Loss: 0.202085
# Epoch 73, Loss: 0.201879
# Epoch 74, Loss: 0.202062
# Epoch 75, Loss: 0.200648
# Epoch 76, Loss: 0.199902
# Epoch 77, Loss: 0.201088
# Epoch 78, Loss: 0.200398
# Epoch 79, Loss: 0.201024
# Epoch 80, Loss: 0.200504
# Epoch 81, Loss: 0.200403
# Epoch 82, Loss: 0.198663
# Epoch 83, Loss: 0.197142
# Epoch 84, Loss: 0.197203
# Epoch 85, Loss: 0.197394
# Epoch 86, Loss: 0.198839
# Epoch 87, Loss: 0.199174
# Epoch 88, Loss: 0.196381
# Epoch 89, Loss: 0.196718
# Epoch 90, Loss: 0.195031
# Epoch 91, Loss: 0.194654
# Epoch 92, Loss: 0.195488
# Epoch 93, Loss: 0.195405
# Epoch 94, Loss: 0.193978
# Epoch 95, Loss: 0.195239
# Epoch 96, Loss: 0.197667
# Epoch 97, Loss: 0.198378
# Epoch 98, Loss: 0.199146
# Epoch 99, Loss: 0.194665
# Epoch 100, Loss: 0.196358

# %%
# 1. Создаём датасет с stride=60 (как для PCA)
dataset_stride60 = SlidingWindowDataset(df, target=None, window_size=60, stride=60)
loader_stride60 = DataLoader(dataset_stride60, batch_size=128, shuffle=False)

# 2. Получаем bottleneck-вектора из энкодера
model.eval()
all_bottlenecks = []

with torch.no_grad():
    for batch, _ in loader_stride60:
        batch = batch.view(batch.size(0), -1).to(device)
        bottleneck = model.encoder(batch)  # shape: [batch_size, 40]
        all_bottlenecks.append(bottleneck.cpu().numpy())

# 3. Собираем всё в один массив
all_bottlenecks = np.concatenate(all_bottlenecks, axis=0)  # shape: [num_windows, 40]

# 4. Сохраняем вектора, например, в .npy или .csv
np.save('bottleneck_vectors.npy', all_bottlenecks)
# или
np.savetxt('bottleneck_vectors.csv', all_bottlenecks, delimiter=',')

print("Bottleneck vectors shape:", all_bottlenecks.shape)
# Out:
# Building safe windows:   0%|          | 0/187 [00:00<?, ?it/s]
# Building safe windows: 100%|██████████| 187/187 [00:00<00:00, 774.62it/s]
# Bottleneck vectors shape: (7803, 40)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# all_bottlenecks — это массив shape [num_windows, 40]
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
X_tsne = tsne.fit_transform(all_bottlenecks)

plt.figure(figsize=(8,6))
plt.scatter(X_tsne[:,0], X_tsne[:,1], alpha=0.5)
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('t-SNE of Bottleneck Vectors')
plt.show()

# %%
trip_numbers = []
for i in range(len(dataset_stride60)):
    # Get the valid window indices
    start_idx, end_idx = dataset_stride60.valid_windows[i]
    # Get the trip number from the first index of this window
    trip_num = df.index[start_idx][0]  # First level of MultiIndex is trip_number
    trip_numbers.append(trip_num)

trip_numbers = np.array(trip_numbers)

tsne = TSNE(n_components=2, random_state=42, perplexity=30)
X_tsne = tsne.fit_transform(all_bottlenecks)

plt.figure(figsize=(10,8))
scatter = plt.scatter(X_tsne[:,0], X_tsne[:,1], c=trip_numbers, alpha=0.7, cmap='viridis')
plt.colorbar(scatter, label='Trip Number')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('t-SNE of Bottleneck Vectors (colored by trip)')
plt.show()

# %%
dfx
# Out:
#         petrol  oil     o1     o2     o3
# 0            0    0  84.07  13.66  166.0
# 1            0    0  84.07  13.66  166.0
# 2            0    0  84.07  13.66  166.0
# 3            0    0  84.07  13.66  166.0
# 4            0    0  84.07  13.66  166.0
# ...        ...  ...    ...    ...    ...
# 473794       6    1  70.34  12.05  169.0
# 473795       6    1  70.34  12.05  169.0
# 473796       6    1  70.34  12.05  169.0
# 473797       6    1  70.34  12.05  169.0
# 473798       6    1  70.34  12.05  169.0
#
# [473799 rows x 5 columns]

# %%
# Extract petrol values for each window (similar to how you got trip_numbers)
petrol_values = []
oil_values = []
o_values = []
for i in range(len(dataset_stride60)):
    # Get the valid window indices
    start_idx, end_idx = dataset_stride60.valid_windows[i]
    # Get the petrol values for this window and take the mean (or median)
    window_petrol = dfx.iloc[start_idx:end_idx]['petrol'].median()  # or .median()
    window_oil = dfx.iloc[start_idx:end_idx]['oil'].median()  # or .median()
    window_o = [dfx.iloc[start_idx:end_idx]['o1'].mean(),
                dfx.iloc[start_idx:end_idx]['o2'].mean(), 
                dfx.iloc[start_idx:end_idx]['o3'].mean()]  # or .median()
    petrol_values.append(window_petrol)
    oil_values.append(window_oil)
    o_values.append(window_o)

petrol_values = np.array(petrol_values)
oil_values = np.array(oil_values)
o_values = np.array(o_values)

# Plot with petrol values as colors
plt.figure(figsize=(10,8))
scatter = plt.scatter(X_tsne[:,0], X_tsne[:,1], c=petrol_values, alpha=0.7, cmap='viridis')
plt.colorbar(scatter, label='Petrol Values')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('t-SNE of Bottleneck Vectors (colored by petrol)')
plt.show()

# Plot with oil values as colors
plt.figure(figsize=(10,8))
scatter = plt.scatter(X_tsne[:,0], X_tsne[:,1], c=oil_values, alpha=0.7, cmap='viridis')
plt.colorbar(scatter, label='Oil Values')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('t-SNE of Bottleneck Vectors (colored by oil)')
plt.show()

# %%
import plotly.express as px
import plotly.graph_objects as go

# Create interactive plot with Plotly
fig = px.scatter(
    x=X_tsne[:, 0], 
    y=X_tsne[:, 1], 
    color=petrol_values,
    hover_data={'Petrol value': petrol_values},
    labels={'x': 't-SNE 1', 'y': 't-SNE 2', 'color': 'Petrol Values'},
    title='Interactive t-SNE of Bottleneck Vectors'
)

fig.show()

# %%
import plotly.express as px
import plotly.graph_objects as go

# Create interactive plot with Plotly
fig = px.scatter(
    x=X_tsne[:, 0], 
    y=X_tsne[:, 1], 
    color=oil_values,
    hover_data={'Oil value': oil_values},
    labels={'x': 't-SNE 1', 'y': 't-SNE 2', 'color': 'Oil Values'},
    title='Interactive t-SNE of Bottleneck Vectors'
)

fig.show()

# %%
# Create 3 separate plots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot 1: o1 values
scatter1 = axes[0].scatter(X_tsne[:,0], X_tsne[:,1], c=o_values[:,0], alpha=0.7, cmap='viridis')
axes[0].set_xlabel('t-SNE 1')
axes[0].set_ylabel('t-SNE 2')
axes[0].set_title('t-SNE colored by o1')
plt.colorbar(scatter1, ax=axes[0], label='o1 Values')

# Plot 2: o2 values
scatter2 = axes[1].scatter(X_tsne[:,0], X_tsne[:,1], c=o_values[:,1], alpha=0.7, cmap='viridis')
axes[1].set_xlabel('t-SNE 1')
axes[1].set_ylabel('t-SNE 2')
axes[1].set_title('t-SNE colored by o2')
plt.colorbar(scatter2, ax=axes[1], label='o2 Values')

# Plot 3: o3 values
scatter3 = axes[2].scatter(X_tsne[:,0], X_tsne[:,1], c=o_values[:,2], alpha=0.7, cmap='viridis')
axes[2].set_xlabel('t-SNE 1')
axes[2].set_ylabel('t-SNE 2')
axes[2].set_title('t-SNE colored by o3')
plt.colorbar(scatter3, ax=axes[2], label='o3 Values')

plt.tight_layout()
plt.show()

# %%
o_values.shape
# Out:
# (7803, 3)

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt

def plot_trip_highlight(trip_to_highlight):
    plt.figure(figsize=(10, 8))
    
    # Plot all points in gray
    plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c='lightgray', alpha=0.5, s=20)
    
    # Highlight selected trip
    if trip_to_highlight in trip_numbers:
        mask = trip_numbers == trip_to_highlight
        plt.scatter(X_tsne[mask, 0], X_tsne[mask, 1], 
                   c='red', alpha=0.8, s=50, label=f'Trip {trip_to_highlight}')
        plt.legend()
    
    plt.xlabel('t-SNE 1')
    plt.ylabel('t-SNE 2')
    plt.title(f't-SNE of Bottleneck Vectors (Trip {trip_to_highlight} highlighted)')
    plt.show()

# Create interactive widget
trip_selector = widgets.IntSlider(
    value=trip_numbers[0],
    min=trip_numbers.min(),
    max=trip_numbers.max(),
    step=1,
    description='Trip:'
)

interactive_plot = widgets.interactive(plot_trip_highlight, trip_to_highlight=trip_selector)
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=1, description='Trip:', max=187, min=1), Output()), _dom_classes=('widge…
