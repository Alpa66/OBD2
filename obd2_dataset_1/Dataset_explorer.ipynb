# %%
# !ls obd2_dataset_1
# Out:
# exp1_14drivers_14cars_dailyRoutes.csv	exp2_19drivers_1car_1route.xlsx
# exp1_14drivers_14cars_dailyRoutes.xlsx	exp3_4drivers_1car_1route.csv
# exp2_19drivers_1car_1route.csv		exp3_4drivers_1car_1route.xlsx

# %%
import pandas as pd
import seaborn as sns

# Import Required Libraries
import matplotlib.pyplot as plt

# Load CSV Data
df = pd.read_csv('./exp3_4drivers_1car_1route.csv')  # Replace 'your_data.csv' with your actual file path

# Display Basic Data Information
print(df.info())
print(df.describe())
print(df.head())

# Visualize Data Distributions
df.hist(figsize=(12, 8))
plt.tight_layout()
plt.show()

# Visualize Correlations
plt.figure(figsize=(10, 8))
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Plot Time Series (if applicable)
# Replace 'date_column' and 'value_column' with actual column names
if 'date_column' in df.columns and 'value_column' in df.columns:
    df['date_column'] = pd.to_datetime(df['date_column'])
    df.set_index('date_column')['value_column'].plot(figsize=(12, 6))
    plt.title('Time Series Plot')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1743 entries, 0 to 1742
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ord                          1743 non-null   int64
#  1   TIME                         1743 non-null   object
#  2   LATITUDE                     1743 non-null   object
#  3   LONGITUDE                    1743 non-null   object
#  4   ALTITUDE                     1743 non-null   float64
#  5   VEHICLE_ID                   1743 non-null   object
#  6   BAROMETRIC_PRESSURE          1720 non-null   float64
#  7   ENGINE_COOLANT_TEMP          1741 non-null   float64
#  8   FUEL_LEVEL                   1741 non-null   object
#  9   ENGINE_LOAD                  1738 non-null   object
#  10  AMBIENT_AIR_TEMP             1740 non-null   float64
#  11  ENGINE_RPM                   1741 non-null   float64
#  12  INTAKE_MANIFOLD_PRESSURE     1743 non-null   int64
#  13  MAF                          1735 non-null   object
#  14  TERM FUEL TRIM BANK 1        0 non-null      float64
#  15  FUEL_ECONOMY                 0 non-null      float64
#  16  LONG TERM FUEL TRIM BANK 2   0 non-null      float64
#  17  FUEL_TYPE                    0 non-null      float64
#  18  AIR_INTAKE_TEMP              1716 non-null   float64
#  19  FUEL_PRESSURE                0 non-null      float64
#  20  SPEED                        1655 non-null   float64
#  21  SHORT TERM FUEL TRIM BANK 2  0 non-null      float64
#  22  SHORT TERM FUEL TRIM BANK 1  1736 non-null   object
#  23  ENGINE_RUNTIME               1741 non-null   object
#  24  THROTTLE_POS                 1732 non-null   object
#  25  DTC_NUMBER                   1638 non-null   object
#  26  TROUBLE_CODES                62 non-null     float64
#  27  TIMING_ADVANCE               827 non-null    object
#  28  EQUIV_RATIO                  826 non-null    object
#  29  aqui                         0 non-null      float64
# dtypes: float64(15), int64(2), object(13)
# memory usage: 408.6+ KB
# None
#                ord     ALTITUDE  BAROMETRIC_PRESSURE  ENGINE_COOLANT_TEMP  \
# count  1743.000000  1743.000000          1720.000000          1741.000000
# mean    872.000000    40.310958            99.796512            85.904078
# std     503.305076     5.844790             0.686773             4.301495
# min       1.000000    16.000000            97.000000            79.000000
# 25%     436.500000    36.000000           100.000000            83.000000
# 50%     872.000000    41.000000           100.000000            84.000000
# 75%    1307.500000    45.000000           100.000000            88.000000
# max    1743.000000    61.000000           101.000000           100.000000
#
#        AMBIENT_AIR_TEMP   ENGINE_RPM  INTAKE_MANIFOLD_PRESSURE  \
# count       1740.000000  1741.000000               1743.000000
# mean           5.902874  1756.306146                 43.161790
# std            3.573800  1010.738357                 23.908868
# min            3.000000     0.000000                 16.000000
# 25%            4.000000  1046.000000                 24.000000
# 50%            4.000000  1518.000000                 35.000000
# 75%            7.000000  2066.000000                 52.000000
# max           17.000000  5994.000000                102.000000
#
#        TERM FUEL TRIM BANK 1  FUEL_ECONOMY  LONG TERM FUEL TRIM BANK 2  \
# count                    0.0           0.0                         0.0
# mean                     NaN           NaN                         NaN
# std                      NaN           NaN                         NaN
# min                      NaN           NaN                         NaN
# 25%                      NaN           NaN                         NaN
# 50%                      NaN           NaN                         NaN
# 75%                      NaN           NaN                         NaN
# max                      NaN           NaN                         NaN
#
#        FUEL_TYPE  AIR_INTAKE_TEMP  FUEL_PRESSURE        SPEED  \
# count        0.0      1716.000000            0.0  1655.000000
# mean         NaN        31.660256            NaN    41.116012
# std          NaN         1.807166            NaN    29.307544
# min          NaN        28.000000            NaN     0.000000
# 25%          NaN        30.000000            NaN    23.000000
# 50%          NaN        31.000000            NaN    37.000000
# 75%          NaN        33.000000            NaN    56.000000
# max          NaN        38.000000            NaN   159.000000
#
#        SHORT TERM FUEL TRIM BANK 2  TROUBLE_CODES  aqui
# count                          0.0           62.0   0.0
# mean                           NaN         4300.0   NaN
# std                            NaN            0.0   NaN
# min                            NaN         4300.0   NaN
# 25%                            NaN         4300.0   NaN
# 50%                            NaN         4300.0   NaN
# 75%                            NaN         4300.0   NaN
# max                            NaN         4300.0   NaN
#    ord      TIME      LATITUDE       LONGITUDE  ALTITUDE VEHICLE_ID  \
# 0    1  1,51E+12  -583.206.639  -3.520.573.159      42.0   control1
# 1    2  1,51E+12  -583.206.639  -3.520.573.159      42.0   control1
# 2    3  1,51E+12  -583.201.429  -3.520.570.624      44.0   control1
# 3    4  1,51E+12    -5.831.937  -3.520.569.123      41.0   control1
# 4    5  1,51E+12  -583.184.493  -3.520.559.225      46.0   control1
#
#    BAROMETRIC_PRESSURE  ENGINE_COOLANT_TEMP FUEL_LEVEL ENGINE_LOAD  ...  \
# 0                100.0                 95.0      56,10       43,10  ...
# 1                100.0                 95.0      56,10       42,00  ...
# 2                100.0                 94.0      56,10       50,60  ...
# 3                100.0                 93.0      56,90       41,20  ...
# 4                100.0                 91.0      56,90       55,70  ...
#
#    SPEED  SHORT TERM FUEL TRIM BANK 2  SHORT TERM FUEL TRIM BANK 1  \
# 0    NaN                          NaN                         0,80
# 1    0.0                          NaN                         0,80
# 2    9.0                          NaN                        -6,20
# 3   10.0                          NaN                         3,10
# 4   11.0                          NaN                         4,70
#
#   ENGINE_RUNTIME  THROTTLE_POS         DTC_NUMBER  TROUBLE_CODES  \
# 0       00:45:33         21,20  MIL is OFF0 codes            NaN
# 1       00:45:37         21,60  MIL is OFF0 codes            NaN
# 2       00:45:41         29,80  MIL is OFF0 codes            NaN
# 3       00:45:45         29,00  MIL is OFF0 codes            NaN
# 4       00:45:49         25,90  MIL is OFF0 codes            NaN
#
#    TIMING_ADVANCE  EQUIV_RATIO  aqui
# 0           52,90         1,00   NaN
# 1           52,50         1,00   NaN
# 2           56,90         1,00   NaN
# 3           71,80         1,00   NaN
# 4           58,00         1,00   NaN
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['TIMESTAMP', 'MARK', 'MODEL', 'CAR_YEAR', 'ENGINE_POWER', 'AUTOMATIC',
#        'VEHICLE_ID', 'BAROMETRIC_PRESSURE(KPA)', 'ENGINE_COOLANT_TEMP',
#        'FUEL_LEVEL', 'ENGINE_LOAD', 'AMBIENT_AIR_TEMP', 'ENGINE_RPM',
#        'INTAKE_MANIFOLD_PRESSURE', 'MAF', 'LONG TERM FUEL TRIM BANK 2',
#        'FUEL_TYPE', 'AIR_INTAKE_TEMP', 'FUEL_PRESSURE', 'SPEED',
#        'SHORT TERM FUEL TRIM BANK 2', 'SHORT TERM FUEL TRIM BANK 1',
#        'ENGINE_RUNTIME', 'THROTTLE_POS', 'DTC_NUMBER', 'TROUBLE_CODES',
#        'TIMING_ADVANCE', 'EQUIV_RATIO', 'MIN', 'HOURS', 'DAYS_OF_WEEK',
#        'MONTHS', 'YEAR'],
#       dtype='object')
